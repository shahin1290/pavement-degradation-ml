# %% [markdown]
# # Phase 2: Feature Engineering & Transformation
# We isolate features, calculate target pavement life ages, and map array datasets for model training.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Load Splitted CSV Data

# %%
train_df = pd.read_csv("../artifacts/train.csv")
test_df = pd.read_csv("../artifacts/test.csv")

# %% [markdown]
# ### 2. Calculate Pavement Age Feature

# %%
for data in [train_df, test_df]:
    data['Pavement_Age'] = 2026 - data['Beläggningsår']

train_df[['Beläggningsår', 'Pavement_Age']].head()
# Out:
#    Beläggningsår  Pavement_Age
# 0           2023             3
# 1           2022             4
# 2           2020             6
# 3           2025             1
# 4           2023             3

# %% [markdown]
# ### 3. Feature Selection

# %%
features = ['Spårdjup max 15', 'ÅDT fordon', 'Pavement_Age', 'Hastighetsgräns', 'Spårdjup max 17', 'Vägbredd']
target = 'IRI höger'

X_train = train_df[features]
y_train = train_df[target]
X_test = test_df[features]
y_test = test_df[target]

print("Features preview:")
print(X_train.head())
# Out:
# Features preview:
#    Spårdjup max 15  ÅDT fordon  Pavement_Age  Hastighetsgräns  \
# 0              7.3          53             3               70
# 1              3.3         496             4               70
# 2              3.2         135             6               70
# 3              2.1       12033             1              120
# 4              5.2        5590             3               80
#
#    Spårdjup max 17  Vägbredd
# 0             9.73       3.7
# 1             5.23       4.5
# 2            12.56       3.5
# 3             2.17      11.5
# 4             9.35       9.0
